# %% [markdown]
# # Python Assignment
# ## Advanced Functions (`*args`, `**kwargs`, `lambda`)
#
# Solve the following questions.

# %% [markdown]
# ### Q1. Write a program using `*args` to find the sum of all numbers.
#
# ```
# Input:
# 10 20 30 40
#
# Output:
# Sum = 100
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q2. Write a program using `*args` to find the largest number.
#
# ```
# Input:
# 15 8 45 22 11
#
# Output:
# Largest Number = 45
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q3. Write a program using `*args` to calculate the average of given numbers.
#
# ```
# Input:
# 10 20 30 40
#
# Output:
# Average = 25.0
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q4. Write a program using `**kwargs` to display student information (Name, Age, Course, City).
#
# ```
# Output:
# Name : Rahul
# Age : 21
# Course : B.Tech
# City : Bhopal
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q5. Write a program using `**kwargs` to display employee details (Name, Salary, Department, Experience).
#
# ```
# Output:
# Name : Amit
# Salary : 45000
# Department : IT
# Experience : 3 Years
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q6. Create a lambda function to find the square of a number.
#
# ```
# Input:
# 6
#
# Output:
# 36
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q7. Create a lambda function to multiply two numbers.
#
# ```
# Input:
# 7 8
#
# Output:
# 56
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q8. Create a lambda function to find the cube of a number.
#
# ```
# Input:
# 4
#
# Output:
# 64
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q9. Create a lambda function to check whether a number is Even or Odd.
#
# ```
# Input:
# 9
#
# Output:
# Odd
# ```

# %%
# Write your code here

# %% [markdown]
# ### Q10. Create a lambda function to find the greater number between two numbers.
#
# ```
# Input:
# 25 40
#
# Output:
# 40
# ```

# %%
# Write your code here

# %% [markdown]
# ### Bonus Q11. Write a program using `*args` to count how many numbers are passed to the function.
#
# ```
# Input:
# 5 10 15 20 25
#
# Output:
# Total Numbers = 5
# ```

# %%
# Write your code here

# %% [markdown]
# ### Bonus Q12. Create a lambda function to calculate `a^b` (power).
#
# ```
# Input:
# 3 4
#
# Output:
# 81
# ```

# %%
# Write your code here
